# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulbhgat/collab-intro/blob/main/intro_to_collab0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2+2
# Out:
# 4

# %%
import torch

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- -----------------
# absl-py                   1.4.0
# accelerate                1.10.1
# aiofiles                  24.1.0
# altair                    5.5.0
# annotated-types           0.7.0
# anyio                     4.10.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# array_record              0.8.1
# arrow                     1.3.0
# attrs                     25.3.0
# audioread                 3.0.1
# backcall                  0.2.0
# beartype                  0.21.0
# beautifulsoup4            4.13.5
# betterproto               2.0.0b6
# bleach                    6.2.0
# blinker                   1.4
# blis                      1.3.0
# cachetools                5.5.2
# catalogue                 2.0.10
# certifi                   2025.8.3
# cffi                      1.17.1
# charset-normalizer        3.4.3
# chex                      0.1.90
# click                     8.2.1
# ...
